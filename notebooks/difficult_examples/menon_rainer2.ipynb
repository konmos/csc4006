# %% [markdown]
# # Story
#
# "For sale. Baby's shoes. Never worn."
#
#
# # Narrative Analysis
#
# ![image.png](attachment:image.png)
#
#
# # User Stories
#
# * As a SELLER I want to...
#     * Sell baby shoes *because I don't need them anymore?/to make money?*
# * As a BUYER I want to...
#     * Buy baby shoes *because I need them?*
#
#
# ![image-2.png](attachment:image-2.png)
